# %%
ls
# Out:
# EDA.ipynb             test_v2.csv
# sampleSubmission.csv  train.csv

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = trn = pd.read_csv("train.csv")
tst = pd.read_csv("test_v2.csv")

trn.head()
# Out:
#    customer_ID  shopping_pt  record_type  day   time state  location  \
# 0     10000000            1            0    0  08:35    IN     10001
# 1     10000000            2            0    0  08:38    IN     10001
# 2     10000000            3            0    0  08:38    IN     10001
# 3     10000000            4            0    0  08:39    IN     10001
# 4     10000000            5            0    0  11:55    IN     10001
#
#    group_size  homeowner  car_age car_value  risk_factor  age_oldest  \
# 0           2          0        2         g            3          46
# 1           2          0        2         g            3          46
# 2           2          0        2         g            3          46
# 3           2          0        2         g            3          46
# 4           2          0        2         g            3          46
#
#    age_youngest  married_couple  C_previous  duration_previous  A  B  C
# ...

# %%
trn.describe()
# Out:
#            customer_ID    shopping_pt    record_type            day  \
# count    665249.000000  665249.000000  665249.000000  665249.000000
# mean   10076553.440219       4.219966       0.145824       1.969429
# std       44049.778593       2.394369       0.352930       1.453470
# min    10000000.000000       1.000000       0.000000       0.000000
# 25%    10038523.000000       2.000000       0.000000       1.000000
# 50%    10076403.000000       4.000000       0.000000       2.000000
# 75%    10114696.000000       6.000000       0.000000       3.000000
# max    10152724.000000      13.000000       1.000000       6.000000
#
#             location     group_size      homeowner        car_age  \
# count  665249.000000  665249.000000  665249.000000  665249.000000
# mean    12271.543022       1.234784       0.536229       8.139437
# std      1564.789415       0.461036       0.498686       5.764598
# min     10001.000000       1.000000       0.000000       0.000000
# ...

# %%
tst.describe()
# Out:
#            customer_ID    shopping_pt  record_type            day  \
# count    198856.000000  198856.000000       198856  198856.000000
# mean   10076080.097261       2.653966            0       1.912359
# std       44103.970222       1.602248            0       1.442332
# min    10000001.000000       1.000000            0       0.000000
# 25%    10037731.000000       1.000000            0       1.000000
# 50%    10076405.000000       2.000000            0       2.000000
# 75%    10114268.000000       4.000000            0       3.000000
# max    10152722.000000      11.000000            0       6.000000
#
#             location     group_size      homeowner        car_age  \
# count  198178.000000  198856.000000  198856.000000  198856.000000
# mean    12322.615855       1.232424       0.539496       8.098317
# std      1592.510709       0.454229       0.498439       5.746131
# min     10001.000000       1.000000       0.000000       0.000000
# ...

# %%
pd.value_counts(df.record_type)
# Out:
# 0    568240
# 1     97009
# dtype: int64

# %%
# Did everyone buy eventually?
df.groupby('customer_ID')['record_type'].max().min()
# Out:
# 1

# %%
# How many shopping_pts
pd.value_counts(df.groupby('customer_ID').size()).sort_index().plot(kind='bar')

# %%
sales = df.query('record_type == 1')

# %%
sns.factorplot('day', data=df, hue="record_type", col="record_type")

# %%
pd.value_counts(df.state)
# Out:
# FL    106287
# NY     91627
# PA     60677
# OH     44537
# MD     28443
# IN     25295
# WA     25188
# CO     24409
# AL     23560
# CT     19353
# TN     18099
# KY     16100
# NV     15459
# MO     15243
# OR     15068
# UT     14820
# OK     13779
# MS     10722
# AR     10460
# WI     10103
# GA      8802
# NH      7988
# ME      6800
# NM      6790
# ID      6110
# RI      5887
# KS      5585
# WV      5053
# IA      4545
# DE      4101
# DC      3748
# MT      3332
# NE      3121
# ND      2487
# WY      1163
# SD       508
# dtype: int64

# %%
sns.factorplot('group_size', data=df, hue="record_type", col="record_type")

# %%
sns.factorplot('car_age', data=df, hue="record_type", col="record_type")

# %%
df.head()
# Out:
#    customer_ID  shopping_pt  record_type  day   time state  location  \
# 0     10000000            1            0    0  08:35    IN     10001
# 1     10000000            2            0    0  08:38    IN     10001
# 2     10000000            3            0    0  08:38    IN     10001
# 3     10000000            4            0    0  08:39    IN     10001
# 4     10000000            5            0    0  11:55    IN     10001
#
#    group_size  homeowner  car_age car_value  risk_factor  age_oldest  \
# 0           2          0        2         g            3          46
# 1           2          0        2         g            3          46
# 2           2          0        2         g            3          46
# 3           2          0        2         g            3          46
# 4           2          0        2         g            3          46
#
#    age_youngest  married_couple  C_previous  duration_previous  A  B  C
# ...
